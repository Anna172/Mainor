# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna172/Mainor/blob/master/%D0%BA%D0%B4%D0%B7%D1%8D%D0%BA%D0%BE%D0%BD%D0%BE%D0%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1b
lrq = [596738, 686513, 779166, 874565, 972576, 1073149, 1176136, 1281434, 1389110, 1498750]
lrtc = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]

# %%
#1b долгосрочнае идержки тс и q lrtc

plt.plot(lrq, lrtc, c='black')
plt.show()

# %%
#1c
lrq = [596738, 686513, 779166, 874565, 972576, 1073149, 1176136, 1281434, 1389110, 1498750]
lrtc = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]

latc = [596738, 686513, 779166, 874565, 972576, 1073149, 1176136, 1281434, 1389110, 1498750]
lmc = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]


for i in range(10):
  latc[i] = lrtc[i]/lrq[i]
  if i == 0:
    lmc[i] = lrtc[i]/lrq[i]
  else:
    lmc[i] = (lrtc[i] - lrtc[i-1])/(lrq[i] - lrq[i-1])
lmc
# Out:
# [0.1675777309304921,
#  1.113895850737956,
#  1.0792958673761237,
#  1.0482290170756507,
#  1.0202936405097387,
#  0.9943026458393406,
#  0.9709963393438007,
#  0.9496856540485099,
#  0.9287120621122628,
#  0.9120758847136081]

# %%
#1c издержки атс и мс, х - выпуск
plt.plot(lrq, latc, c='black')
plt.plot(lrq, lmc)
plt.show()

# %%
#2.1
l = np.array(range(0,120))
tpl = -l**3+110*(l**2)+8735*l

# %%
#2.1
plt.plot(l, tpl, c='black')
plt.show()

# %%
#2.1
srapl = -(l**2)+110*l+8735
srmpl= -3*l**2+220*l+8735

# %%
#2.1 l=x, q=y
plt.plot(l, srapl)
plt.plot(l, srmpl, c='black')
plt.show()

# %%
# 2. Издержки производства

# %%
#2b k = 4010

lrq5 = [596738, 686513, 779166, 874565, 972576] 
srtc5 = [451800, 459400, 468000, 478800, 500000]
lrtc5 = [100000, 200000, 300000, 400000, 500000]

# %%
#2b
plt.plot(lrq5, srtc5)
plt.plot(lrq5, lrtc5, c='green')
plt.show()

# %%
#2c

latc5 = [596738, 686513, 779166, 874565, 972576]
lmc5 = [100000, 200000, 300000, 400000, 500000]
satc5 = [596738, 686513, 779166, 874565, 972576]
smc5 = [100000, 200000, 300000, 400000, 500000]


for i in range(5):
  satc5[i] = srtc5[i]/lrq5[i]
  latc5[i] = lrtc5[i]/lrq5[i]
  if i == 0:
    smc5[i] = srtc5[i]/lrq5[i]
    lmc5[i] = lrtc5[i]/lrq5[i]
  else:
    smc5[i] = (srtc5[i] - srtc5[i-1])/(lrq5[i] - lrq5[i-1])
    lmc5[i] = (lrtc5[i] - lrtc5[i-1])/(lrq5[i] - lrq5[i-1])

# %%
#2с
# х - выпуск, у - 

plt.plot(lrq5, smc5, c='black')
plt.plot(lrq5, satc5)

plt.plot(lrq5, lmc5, c='red')
plt.plot(lrq5, latc5, c='green')
plt.show()

# %%
# 2d k = 5000 tc=200000

lrq2 = [596738, 686513] 
srtc2 = [177900, 200000]
lrtc2 = [100000, 200000]

plt.plot(lrq2, srtc2)
plt.plot(lrq2, lrtc2, c='green')
plt.show()

# %%
# 2d k = 5000 tc=200000

latc2 = [596738, 686513]
lmc2 = [100000, 200000]
satc2 = [596738, 686513]
smc2 = [100000, 200000]


for i in range(2):
  satc2[i] = srtc2[i]/lrq2[i]
  latc2[i] = lrtc2[i]/lrq2[i]
  if i == 0:
    smc2[i] = srtc2[i]/lrq2[i]
    lmc2[i] = lrtc2[i]/lrq2[i]
  else:
    smc2[i] = (srtc2[i] - srtc2[i-1])/(lrq2[i] - lrq2[i-1])
    lmc2[i] = (lrtc2[i] - lrtc2[i-1])/(lrq2[i] - lrq2[i-1])

plt.plot(lrq2, smc2, c='black')
plt.plot(lrq2, satc2)

plt.plot(lrq2, lmc2, c='red')
plt.plot(lrq2, latc2, c='green')
plt.show()

# %%
# 2d k = 5000 tc=400000

lrq4 = [596738, 686513, 779166, 874565] 
srtc4 = [358600, 367400, 378300, 400000]
lrtc4 = [100000, 200000, 300000, 400000]

plt.plot(lrq4, srtc4)
plt.plot(lrq4, lrtc4, c='green')
plt.show()

# %%
# 2d k = 5000 tc=400000

latc4 = [596738, 686513, 779166, 874565]
lmc4 = [100000, 200000, 300000, 400000]
satc4 = [358600, 358600, 779166, 874565]
smc4 = [100000, 200000, 300000, 400000]


for i in range(4):
  satc4[i] = srtc4[i]/lrq4[i]
  latc4[i] = lrtc4[i]/lrq4[i]
  if i == 0:
    smc4[i] = srtc4[i]/lrq4[i]
    lmc4[i] = lrtc4[i]/lrq4[i]
  else:
    smc4[i] = (srtc4[i] - srtc4[i-1])/(lrq4[i] - lrq4[i-1])
    lmc4[i] = (lrtc4[i] - lrtc4[i-1])/(lrq4[i] - lrq4[i-1])

plt.plot(lrq4, smc4, c='black')
plt.plot(lrq4, satc4)

plt.plot(lrq4, lmc4, c='red')
plt.plot(lrq4, latc4, c='green')
plt.show()

# %%
# 2d k = 5000 tc=600000

lrq6 = [596738, 686513, 779166, 874565, 972576, 1073149] 
srtc6 = [545400, 552300, 559700, 568300, 578800, 600000]
lrtc6 = [100000, 200000, 300000, 400000, 500000, 600000]

plt.plot(lrq6, srtc6)
plt.plot(lrq6, lrtc6, c='green')
plt.show()

# %%
# 2d k = 5000 tc=600000

latc6 = [596738, 686513, 779166, 874565, 972576, 972576]
lmc6 = [100000, 200000, 300000, 400000, 500000, 972576]
satc6 = [596738, 686513, 779166, 874565, 972576, 972576]
smc6 = [100000, 200000, 300000, 400000, 500000, 972576]


for i in range(6):
  satc6[i] = srtc6[i]/lrq6[i]
  latc6[i] = lrtc6[i]/lrq6[i]
  if i == 0:
    smc6[i] = srtc6[i]/lrq6[i]
    lmc6[i] = lrtc6[i]/lrq6[i]
  else:
    smc6[i] = (srtc6[i] - srtc6[i-1])/(lrq6[i] - lrq6[i-1])
    lmc6[i] = (lrtc6[i] - lrtc6[i-1])/(lrq6[i] - lrq6[i-1])

plt.plot(lrq6, smc6, c='black')
plt.plot(lrq6, satc6)

plt.plot(lrq6, lmc6, c='red')
plt.plot(lrq6, latc6, c='green')
plt.show()

# %%
# 2d k = 5000 tc=800000

lrq8 = [596738, 686513, 779166, 874565, 972576, 1073149, 1176136, 1281434] 
srtc8 = [735200, 741000, 747000, 753600, 760800, 769100, 779500, 800000]
lrtc8 = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000]

plt.plot(lrq8, srtc8)
plt.plot(lrq8, lrtc8, c='green')
plt.show()

# %%
# 2d k = 5000 tc=800000

latc8 = [596738, 686513, 779166, 874565, 972576, 600000, 700000, 800000]
lmc8 = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000]
satc8 = [596738, 686513, 779166, 874565, 972576, 600000, 700000, 800000]
smc8 = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000]


for i in range(8):
  satc8[i] = srtc8[i]/lrq8[i]
  latc8[i] = lrtc8[i]/lrq8[i]
  if i == 0:
    smc8[i] = srtc8[i]/lrq8[i]
    lmc8[i] = lrtc8[i]/lrq8[i]
  else:
    smc8[i] = (srtc8[i] - srtc8[i-1])/(lrq8[i] - lrq8[i-1])
    lmc8[i] = (lrtc8[i] - lrtc8[i-1])/(lrq8[i] - lrq8[i-1])

plt.plot(lrq8, smc8, c='black')
plt.plot(lrq8, satc8)

plt.plot(lrq8, lmc8, c='red')
plt.plot(lrq8, latc8, c='green')
plt.show()

# %%
# 2e total
plt.plot(lrq2, srtc2)
plt.plot(lrq4, srtc4, c='yellow')
plt.plot(lrq5, srtc5, c='purple')
plt.plot(lrq6, srtc6, c='black')
plt.plot(lrq8, srtc8, c='orange')
plt.plot(lrq8, lrtc8, c='green')
plt.show()

# %%
# 2e avarage and marginal
plt.plot(lrq2, smc2)
plt.plot(lrq2, satc2, c='black')
plt.plot(lrq4, smc4, c='yellow')
plt.plot(lrq4, satc4, c='gray')
plt.plot(lrq5, smc5, c='purple')
plt.plot(lrq5, satc5, c='blue')
plt.plot(lrq6, smc6, c='black')
plt.plot(lrq6, satc6, c='brown')
plt.plot(lrq8, smc8, c='orange')
plt.plot(lrq8, satc8, c='pink')

plt.plot(lrq8, lmc8, c='red')
plt.plot(lrq8, latc8, c='green')
plt.show()

# %%
# 3.1
#1c издержки атс и мс, х - выпуск
plt.plot(lrq, latc, c='black')
plt.plot(lrq, lmc)
plt.show()

# %%
# 3.2
#2с
# х - выпуск, у - 

plt.plot(lrq5, smc5)
plt.plot(lrq5, satc5, c='black')

plt.show()
